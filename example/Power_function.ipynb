# %% [markdown]
# # Plot Power Function

# %% [markdown]
# ## Import matplotlib and numpy

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Define the argument as a numpy array

# %%
np_arange_args={'start':-10,'stop':10,'step':0.01}

# %%
x=np.arange(**np_arange_args)

# %% [markdown]
# ## Define the exponent

# %%
exponent=2

# %% [markdown]
# ## Define the function

# %%
y=x**exponent

# %% [markdown]
# ## Plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title('y = x raised to the power of '+str(exponent),fontsize=20)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.plot(x,y)
plt.show()
